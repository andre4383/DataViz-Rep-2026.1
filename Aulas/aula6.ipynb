# %% [markdown]
# ## Introdução
#
# Na aula passada, aprendemos a acessar a API do IBGE, identificar uma série de interesse e extrair os dados. A atividade proposta consistiu em obter o conjunto de dados para três categorias: total, homens e mulheres. Nesta etapa, daremos início à análise exploratória desses dados. Para isso, observe o conjunto apresentado a seguir e responda às questões propostas.

# %% [markdown]
# ## Conjunto Gerado

# %%
url = "https://docs.google.com/spreadsheets/d/1BRIthYFiT3i39WGEk3AQd24BH8rT4EokJ4WsEiMp1jE/export?format=csv"

# %%
import pandas as pd

df = pd.read_csv(url)

# %%
df_filtrado = df.query('total!=0 and mulheres!=0 and homens!=0')
